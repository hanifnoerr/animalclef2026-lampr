# %%
from pathlib import Path
import sys

repo = Path.cwd()
for candidate in [repo, *repo.parents]:
    if (candidate / "paper_submissions_manifest.csv").exists():
        repo = candidate
        break

sys.path.insert(0, str(repo / "src"))

# %%
from reproduce_submission import reproduce_submission

path, digest, row = reproduce_submission("sea_turtle_eva02_aliked_local_link_refinement")
print(path)
print(digest)
print(row["public_ari"], row["private_ari"])
