# %%
from pathlib import Path
import shutil
import sys

repo = Path.cwd()
for candidate in [repo, *repo.parents]:
    if (candidate / "paper_submissions_manifest.csv").exists():
        repo = candidate
        break
sys.path.insert(0, str(repo / "src"))

from notebook_tools import animalclef_data_root, run_module_main, verify_submission

DATA_ROOT = animalclef_data_root(repo)

# %%
SLUG = "anatomy_template_registration"
OUTPUT_ROOT = repo / "runs/anatomy_template_registration"
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

# %%
MODULE = "species_anatomy_template_registration_v20260426"
ARGS = [
    "--data-root",
    str(DATA_ROOT),
    "--output-root",
    str(OUTPUT_ROOT),
]

# %%
run_module_main(MODULE, ARGS)

# %%
source = OUTPUT_ROOT / "submissions" / "submission_species_anatomy_template_registration_v20260426_strict.csv"
shutil.copyfile(source, OUTPUT_ROOT / "submission.csv")

# %%
produced = OUTPUT_ROOT / "submission.csv"
verify_submission(produced, SLUG, repo)
